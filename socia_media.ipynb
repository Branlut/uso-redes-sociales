# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('HybridDataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 19 columns):
#  #   Column                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                               --------------  -----
#  0   Unnamed: 0                                                                                           310 non-null    int64
#  1   what is your age group?                                                                              310 non-null    object
#  2   what is your occupation?                                                                             310 non-null    object
#  3   how many hours per day do you spend online?                                                          310 non-null    object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 what is your age group? what is your occupation?  \
# 0           0                   18-24                  Student
# 1           1                   18-24     Working Professional
# 2           2                   18-24                  Student
# 3           3                   35-44                  Student
# 4           4                   25-34     Working Professional
#
#   how many hours per day do you spend online?  \
# 0                                 Less than 2
# 1                                 Less than 2
# 2                                       "6-8"
# 3                                 Less than 2
# 4                                       "2-4"
#
#   what device do you use most to access the internet?  \
# 0                                         Smartphone
# 1                                         Smartphone
# 2                                         Smartphone
# 3                                    Laptop/Computer
# ...

# %%
columns_name = {'Unnamed: 0':'serial_number','what is your age group?':'age_group','what is your occupation?':'ocupation','how many hours per day do you spend online?':'hours_spend',
                'what device do you use most to access the internet?':'device_acces','what is the total number of social media platforms that you use?':'social_plataforms',
                'which social media platforms do you use regularly?':'regular_plataforms','what is your most used social media platform?':'most_used','could you spend an entire week without social media?':'week_without_social',
                'the first thing you do after walking up is scroll through your social media account.':'wake_up_scroll','what do you primarily use the internet for?':'internet_use',
                'which activities do you engage in most on social media?':'plataform_activities','do you purchase premium subscriptions for social media platforms? (like spotify or netflix premium)':'subscriptions',
                'how often do you find yourself distracted while working or studying due to social media?':'distracted','do you use tools or apps to manage distractions?':'app_distraction',
                'what types of notifications or distractions affect you the most?':'types_distractions','have you ever paid to support a content creator? (e.g., membership, subscription)':'paid_content_creator',
                'do you feel like attention is being monetized by platforms?':'monetized_attention'}

df =df.rename(columns=columns_name)

# %%
df.head()
# Out:
#    serial_number age_group             ocupation  hours_spend  \
# 0              0     18-24               Student  Less than 2
# 1              1     18-24  Working Professional  Less than 2
# 2              2     18-24               Student        "6-8"
# 3              3     35-44               Student  Less than 2
# 4              4     25-34  Working Professional        "2-4"
#
#       device_acces social_plataforms                 regular_plataforms  \
# 0       Smartphone               4 +        [Snapchat, Twitch, Spotify]
# 1       Smartphone                 3  [Facebook, Instagram, X, Spotify]
# 2       Smartphone               4 +     [Facebook, Reddit, X, YouTube]
# 3  Laptop/Computer               4 +                [Snapchat, YouTube]
# 4       Smartphone               4 +                     [X, Pinterest]
#
#    most_used      week_without_social  \
# 0    YouTube           Yes, ofcourse.
# 1    YouTube           Yes, ofcourse.
# ...

# %%
df['regular_plataforms']=df['regular_plataforms'].str.split(', ')

# %%
df.head(3)
df_regular_explode = df['regular_plataforms'].explode()
df_regular_encoded = pd.get_dummies(df_regular_explode).groupby(level=0).max()

# %%
df_regular_encoded
# Out:
#      Chrome  Facebook  Instagram  LinkedIn  Pinterest  Reddit  Snapchat  \
# 0     False     False      False     False      False   False      True
# 1     False      True       True     False      False   False     False
# 2     False      True      False     False      False    True     False
# 3     False     False      False     False      False   False      True
# 4     False     False      False     False       True   False     False
# ..      ...       ...        ...       ...        ...     ...       ...
# 305   False     False       True      True       True   False     False
# 306   False     False       True     False      False   False     False
# 307   False      True      False      True      False   False     False
# 308   False     False       True     False      False   False      True
# 309   False      True      False      True      False   False     False
#
#      Spotify  Telegram  Tiktok  ...  Twitch  What's app   WhatsApp   Whatsapp  \
# ...

# %%
test = Counter(df_regular_explode)

# %%
test
# Out:
# Counter({'YouTube': 138,
#          'Instagram': 125,
#          'Spotify': 108,
#          'LinkedIn': 101,
#          'Pinterest': 82,
#          'Snapchat': 77,
#          'Telegram': 59,
#          'Whatsapp': 52,
#          'Reddit': 47,
#          'Tiktok': 47,
#          'Twitch': 45,
#          'Facebook': 45,
#          'X': 43,
#          'X (Formerly Twitter)': 9,
#          'WhatsApp ': 5,
#          'Whatsapp ': 2,
#          'youtube music ': 1,
#          'whatasapp': 1,
#          'Tumblr': 1,
#          'Chrome': 1,
#          "What's app ": 1})

# %%
print(df_regular_encoded.sum(axis=1))
# Out:
# 0      3
# 1      4
# 2      4
# 3      2
# 4      2
#       ..
# 305    4
# 306    4
# 307    4
# 308    4
# 309    3
# Length: 310, dtype: int64
